# %%
# Load modules
import os
import json
import sys
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.context import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.ml import PipelineModel
import threading

# %%
# Helper thread to avoid the Spark StreamingContext from blocking Jupyter    
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
# If saved model doesn't load, retrain.
# from nltk.corpus import stopwords
# from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml import Pipeline

# df_pandas_orig = pd.read_csv("DF_Streaming.csv")
# df_pandas = df_pandas_orig.dropna(inplace=False)
# df_spark = spark.createDataFrame(df_pandas)
# training_data, test_data = df_spark.randomSplit([0.8, 0.2], seed = 100)

# stop_words = set(stopwords.words('english'))
# tokenizer = Tokenizer(inputCol="review_text", outputCol="words") # stop words
# stopwords_remover = StopWordsRemover(inputCol="words", outputCol="filtered").setStopWords(list(stop_words))
# count_vectors = CountVectorizer(inputCol="filtered", outputCol="features", vocabSize=10000, minDF=5)
# lr_model = LogisticRegression(maxIter=20, regParam=0.3, elasticNetParam=0.0)
# pipeline_lr = Pipeline(stages=[tokenizer, stopwords_remover, count_vectors, lr_model])
# fitted_pipeline_lr = pipeline_lr.fit(training_data)

# %%
# Prediction code from saved model
globals()['models_loaded'] = True
globals()['my_model'] = PipelineModel.load('models/score_classifier_lr')

def process(time, rdd):
    if rdd.isEmpty():
        return    
    print("========= %s =========" % str(time))    
    # Convert to data frame
    input = spark.read.json(rdd)
    prediction = globals()['my_model'].transform(input)
    # prediction = fitted_pipeline_lr.transform(input)
    prediction.select("review_id", "app_id", "review_text", "label", "prediction").show()

# %%
# Set environment variables for Spark
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# Start spark session
spark = SparkSession.builder.appName('Spark_Predictions').getOrCreate()
sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local[*] appName=Spark_Predictions>

# %%
ssc = StreamingContext(sc, 10)
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
# Start the review stream
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# ========= 2023-05-28 20:38:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164398|1559600|It's actually a w...|    1|       1.0|
# |139164444|2355750|           Good game|    1|       1.0|
# |139165010| 705040|I'm really hurt.\...|    0|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:39:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139161195|2413140|Titor's Time Trav...|    1|       0.0|
# |139165474|1934780|8/10 - Great grap...|    1|       1.0|
# |139163329|1934780|really fun its li...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:39:10 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139162663|1934780|take long to find...|    0|       1.0|
# |139161244|2248760|Played about 11 h...|    1|       1.0|
# |139165245| 754890|Bafflingly ..."No...|    0|       0.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:39:20 =========
# +---------+------+--------------------+-----+----------+
# |review_id|app_id|         review_text|label|prediction|
# +---------+------+--------------------+-----+----------+
# |139164855|754890|Enjoyed my time q...|    1|       1.0|
# +---------+------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:39:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165024|1899060|POCKET MIRROR IS ...|    1|       1.0|
# |139164620|2284260|Step right up, fo...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:39:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164982|1062810|Beat a run and th...|    0|       1.0|
# |139162996|1952590|A surprisingly ee...|    1|       1.0|
# |139164565|2141910|I have come to re...|    0|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:39:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166018|1649010|Full disclosure, ...|    1|       1.0|
# |139162493|1649010|If you are a fan ...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:40:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139162491|1649010|First and foremos...|    0|       0.0|
# |139164040|1683420|Well I played all...|    1|       1.0|
# |139163400|1276800|Better than Leagu...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:40:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166303|2005010|           Good game|    1|       1.0|
# |139166299|2005010|Works great on st...|    1|       1.0|
# |139166066|2005010|Enable modding su...|    1|       1.0|
# |139165955|2005010|KILL THE WARP SPA...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:40:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165869|2005010|my expectations w...|    1|       1.0|
# |139165763|2005010| Praise the Emperor!|    1|       1.0|
# |139165632|2005010|Limited color pal...|    0|       1.0|
# |139165422|2005010|What the fuck did...|    1|       0.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:40:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165248|2005010|I almost forgot g...|    1|       1.0|
# |139165172|2005010|very relaxing gam...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:41:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164024|1724980|The Lone Blade is...|    1|       1.0|
# |139164938|2154650|i got this cause ...|    1|       1.0|
# |139164926|2218750|It's the same pri...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:41:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164251|2218750|               10/10|    1|       1.0|
# |139164097|2218750|Very nice, I had ...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:41:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139162677|2218750|          Tormentor!|    1|       1.0|
# |139162174|2218750|Most fun I have h...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:41:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139162091|2218750|hands down the be...|    1|       1.0|
# |139162032|2218750|           super fun|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:42:00 =========
# +---------+-------+-----------+-----+----------+
# |review_id| app_id|review_text|label|prediction|
# +---------+-------+-----------+-----+----------+
# |139161876|2218750|  best game|    1|       1.0|
# +---------+-------+-----------+-----+----------+
#
# ========= 2023-05-28 20:42:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139163835|1265780|      Just not good.|    0|       1.0|
# |139166281|1589120|Great game with a...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:42:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165673|1589120|There are Jackalo...|    1|       1.0|
# |139164056|1127840|For me, at least,...|    0|       1.0|
# |139163976|1964040|Good day develope...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:42:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139163241|1644320|Great time killer...|    1|       1.0|
# |139163149|2103480|Simple yet fun an...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:42:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166704|1938800|A short prologue ...|    1|       1.0|
# |139166602|1938800|dont bother its o...|    0|       1.0|
# |139166497|1938800|It's short, has n...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:43:10 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166698|2231560|this game it take...|    1|       1.0|
# |139164053|2422080|Good game but can...|    1|       1.0|
# |139163044|2422080|I loved Plants vs...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:43:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166077|2298300|In my humble opin...|    1|       1.0|
# |139164642|1999740|Number go up...\n...|    1|       1.0|
# |139165590|1969150|The game is good,...|    1|       1.0|
# |139164623|1969150|I think overall i...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:43:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164481|1969150|This game could b...|    0|       1.0|
# |139166096|2102640|Fun game to play ...|    1|       1.0|
# |139166045|2140510|Enough change for...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:43:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166541|2219690|Progression and s...|    0|       1.0|
# |139164878|1686290|Played for a few ...|    0|       0.0|
# |139162970|2411830|The game feels li...|    0|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 20:44:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |134231852|2222530|Best game I've ev...|    1|       1.0|
# |130879244|2222530|          moborcydle|    1|       1.0|
# |130874571|2222530|For a dollar and ...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:14:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164398|1559600|It's actually a w...|    1|       1.0|
# |139164444|2355750|           Good game|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:15:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165010| 705040|I'm really hurt.\...|    0|       1.0|
# |139161195|2413140|Titor's Time Trav...|    1|       0.0|
# |139165474|1934780|8/10 - Great grap...|    1|       1.0|
# |139163329|1934780|really fun its li...|    1|       1.0|
# |139162663|1934780|take long to find...|    0|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:27:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164565|2141910|I have come to re...|    0|       1.0|
# |139166018|1649010|Full disclosure, ...|    1|       1.0|
# |139162493|1649010|If you are a fan ...|    1|       1.0|
# |139162491|1649010|First and foremos...|    0|       0.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:27:10 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164040|1683420|Well I played all...|    1|       1.0|
# |139163400|1276800|Better than Leagu...|    1|       1.0|
# |139166303|2005010|           Good game|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:27:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166299|2005010|Works great on st...|    1|       1.0|
# |139166066|2005010|Enable modding su...|    1|       1.0|
# |139165955|2005010|KILL THE WARP SPA...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:27:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164024|1724980|The Lone Blade is...|    1|       1.0|
# |139164938|2154650|i got this cause ...|    1|       1.0|
# |139164926|2218750|It's the same pri...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:28:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164251|2218750|               10/10|    1|       1.0|
# |139164097|2218750|Very nice, I had ...|    1|       1.0|
# |139162677|2218750|          Tormentor!|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:28:10 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139162174|2218750|Most fun I have h...|    1|       1.0|
# |139162091|2218750|hands down the be...|    1|       1.0|
# |139162032|2218750|           super fun|    1|       1.0|
# |139161876|2218750|           best game|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:28:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139163835|1265780|      Just not good.|    0|       1.0|
# |139166281|1589120|Great game with a...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:28:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165673|1589120|There are Jackalo...|    1|       1.0|
# |139164056|1127840|For me, at least,...|    0|       1.0|
# |139163976|1964040|Good day develope...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:28:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139163241|1644320|Great time killer...|    1|       1.0|
# |139163149|2103480|Simple yet fun an...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:29:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166704|1938800|A short prologue ...|    1|       1.0|
# |139166602|1938800|dont bother its o...|    0|       1.0|
# |139166497|1938800|It's short, has n...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:29:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166698|2231560|this game it take...|    1|       1.0|
# |139164053|2422080|Good game but can...|    1|       1.0|
# |139163044|2422080|I loved Plants vs...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:29:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166077|2298300|In my humble opin...|    1|       1.0|
# |139164642|1999740|Number go up...\n...|    1|       1.0|
# |139165590|1969150|The game is good,...|    1|       1.0|
# |139164623|1969150|I think overall i...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:29:50 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139164481|1969150|This game could b...|    0|       1.0|
# |139166096|2102640|Fun game to play ...|    1|       1.0|
# |139166045|2140510|Enough change for...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:30:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139166541|2219690|Progression and s...|    0|       1.0|
# |139164878|1686290|Played for a few ...|    0|       0.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:30:30 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139162970|2411830|The game feels li...|    0|       1.0|
# |134231852|2222530|Best game I've ev...|    1|       1.0|
# |130879244|2222530|          moborcydle|    1|       1.0|
# |130874571|2222530|For a dollar and ...|    1|       1.0|
# |139165927| 605740|As a real life fi...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:30:40 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139168750|1581480|Not without its f...|    1|       1.0|
# |139168668|1581480|A perfect little ...|    1|       1.0|
# |139168602| 824600|This game is pret...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:31:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139168873| 705040|As a fan of the p...|    1|       1.0|
# |139168743|1268750|my system could n...|    1|       1.0|
# |139168569|1268750|Definitely perfor...|    0|       1.0|
# |139168303|1268750|Come on, you apes...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:31:10 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139168268|1268750|Great way to beco...|    1|       1.0|
# |139168091|1268750|The game is full ...|    1|       1.0|
# |139167886|1268750|Overall its fun a...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:31:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139167838|1268750|   ACTION package!!!|    1|       1.0|
# |139167623|1268750|You guy's th-ther...|    1|       1.0|
# |139167457|1268750|         kill em all|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:31:50 =========
# +---------+-------+-----------+-----+----------+
# |review_id| app_id|review_text|label|prediction|
# +---------+-------+-----------+-----+----------+
# |139166583|2418820|Excellent!!|    1|       1.0|
# +---------+-------+-----------+-----+----------+
#
# ========= 2023-05-28 21:32:00 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139168453|1934780|Surprisingly good...|    1|       1.0|
# |139168393|1934780|This game aint th...|    1|       1.0|
# |139167968|1934780|                 Fun|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:32:10 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139168601|2248760|This game is very...|    1|       1.0|
# |139166951|2248760|7hrs and im a mil...|    1|       1.0|
# |139166323|2248760|i think that this...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:32:20 =========
# +---------+-------+--------------------+-----+----------+
# |review_id| app_id|         review_text|label|prediction|
# +---------+-------+--------------------+-----+----------+
# |139165831|2248760|                  yO|    1|       1.0|
# |139169569|1304930|Best Horror Game ...|    1|       1.0|
# |139169429|1304930|This game is an a...|    1|       1.0|
# +---------+-------+--------------------+-----+----------+
#
# ========= 2023-05-28 21:32:40 =========
# +---------+------+--------------------+-----+----------+
# |review_id|app_id|         review_text|label|prediction|
# +---------+------+--------------------+-----+----------+
# |139167459|754890|Absolute magic as...|    1|       1.0|
# |139165958|754890|I give Firmament ...|    1|       1.0|
# +---------+------+--------------------+-----+----------+

# %%
ssc_t.stop()
# Out:
# ----- Stopping... this may take a few seconds -----
